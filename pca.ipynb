# %%
# !pip install ucimlrepo
from ucimlrepo import fetch_ucirepo 
  
# fetch dataset 
wine = fetch_ucirepo(id=109) 
  
# data (as pandas dataframes) 
X = wine.data.features 
y = wine.data.targets

# %%
X.isnull().sum()
# Out:
# Alcohol                         0
# Malicacid                       0
# Ash                             0
# Alcalinity_of_ash               0
# Magnesium                       0
# Total_phenols                   0
# Flavanoids                      0
# Nonflavanoid_phenols            0
# Proanthocyanins                 0
# Color_intensity                 0
# Hue                             0
# 0D280_0D315_of_diluted_wines    0
# Proline                         0
# dtype: int64

# %%
from sklearn.decomposition import PCA

# %%
reduce=PCA(n_components=3)

# %%
x_new=reduce.fit_transform(X)

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# %%
fig,axes=plt.subplots(1,2)
sns.heatmap(X, ax=axes[0], cmap='viridis', annot=True, fmt='.2f', cbar=True)
sns.heatmap(x_new, ax=axes[1], cmap='viridis', annot=True, fmt='.2f', cbar=True)
# Out:
# <AxesSubplot: >
